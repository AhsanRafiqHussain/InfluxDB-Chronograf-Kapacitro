# %%
from influxdb import InfluxDBClient
import pandas as pd
json_body = []

# %%
#assets= pd.read_clipboard()
cities = assets
cities

# %%
for index, row in cities.iterrows():
    json_body.append({
        "measurement": "state_city",
        "tags": {
            "country": row['country'],
            "state": row['state'],
            "city_status":row['city_status'],
            "short_2":row['short_2'],
            "short_3":row['short_3']
        },
        "fields": {
            "city":row['city'],
            "lat":row['lat'],
            "lng":row['lng'],
        }
    })

# %%
#json_body

# %%
client = InfluxDBClient('localhost', 8086)

# %%
client.create_database('example')
client.switch_database('example')

# %%
client.write_points(json_body)

# %%
result = client.query('select * from state_city;')

# %%
print("Result: {0}".format(result))
